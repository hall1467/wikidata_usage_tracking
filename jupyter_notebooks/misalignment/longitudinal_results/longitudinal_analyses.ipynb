# %%
library(data.table)

# %%
library(fmsb)

# %%
library(ggplot2)

# %%
longitudinal_misalignment <- read.table("../../../results/sql_queries/monthly_wikidata_editors/misalignment_and_edits_post_processed.tsv", header=TRUE, sep="\t")

# %%
summary(longitudinal_misalignment)
# Out:
#      yyyymm       aligned_entities difference_in_alignment_with_previous
#  Min.   :201211   Min.   :0.4443   Min.   :-0.0510158
#  1st Qu.:201356   1st Qu.:0.4869   1st Qu.:-0.0141284
#  Median :201502   Median :0.5656   Median :-0.0079630
#  Mean   :201470   Mean   :0.6260   Mean   : 0.0080788
#  3rd Qu.:201604   3rd Qu.:0.7723   3rd Qu.:-0.0003932
#  Max.   :201705   Max.   :0.9063   Max.   : 0.7595628
#    bot_edits        semi_automated_edits non_bot_edits       anon_edits
#  Min.   :     703   Min.   :      0      Min.   : 171640   Min.   :  507
#  1st Qu.: 4352991   1st Qu.:   8720      1st Qu.: 824932   1st Qu.:26771
#  Median : 5456289   Median :  13368      Median :1685156   Median :32242
#  Mean   : 6085124   Mean   : 941996      Mean   :1557141   Mean   :30296
#  3rd Qu.: 8082804   3rd Qu.:1423934      3rd Qu.:1975442   3rd Qu.:36575
#  Max.   :14463573   Max.   :6438773      Max.   :4087993   Max.   :50381
#    all_edits        current_bot_edits_count current_semi_automated_edits_count
#  Min.   :  265340   Min.   :      703       Min.   :       0
#  1st Qu.: 5970844   1st Qu.: 83054754       1st Qu.:  113653
#  Median : 8649502   Median :158955916       Median :  263928
#  Mean   : 8614558   Mean   :160575202       Mean   : 7531503
#  3rd Qu.:10740624   3rd Qu.:240787699       3rd Qu.: 5998294
#  Max.   :18052240   Max.   :334681840       Max.   :51809778
#  current_non_bot_edits_count current_anon_edits_count current_all_edits_count
#  Min.   :  264130            Min.   :    507          Min.   :   265340
#  1st Qu.: 8360335            1st Qu.: 379128          1st Qu.: 91907870
#  Median :28465177            Median : 834166          Median :188519187
#  Mean   :34034745            Mean   : 786484          Mean   :202927933
#  3rd Qu.:59872764            3rd Qu.:1174675          3rd Qu.:307833432
#  Max.   :85642776            Max.   :1666280          Max.   :473800674

# %%
first_month_trimmed_longitudinal_misalignment <- longitudinal_misalignment[2:55,]

# %%
# bot edits over all edits versus alignment

# %%
cor(longitudinal_misalignment$aligned_entities, longitudinal_misalignment$bot_edits/longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] 0.7071429

# %%
summary(lm(longitudinal_misalignment$bot_edits/longitudinal_misalignment$all_edits ~ longitudinal_misalignment$aligned_entities))
# Out:
# Call:
# lm(formula = longitudinal_misalignment$bot_edits/longitudinal_misalignment$all_edits ~
#     longitudinal_misalignment$aligned_entities)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.78706 -0.03986  0.03745  0.08670  0.24310
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                 0.31717    0.08978   3.533 0.000861
# longitudinal_misalignment$aligned_entities  0.62211    0.13935   4.464 4.23e-05
#
# (Intercept)                                ***
# longitudinal_misalignment$aligned_entities ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1575 on 53 degrees of freedom
# Multiple R-squared:  0.2733,	Adjusted R-squared:  0.2596
# F-statistic: 19.93 on 1 and 53 DF,  p-value: 4.234e-05

# %%
# semi-automated edits over all edits versus alignment

# %%
cor(longitudinal_misalignment$aligned_entities, longitudinal_misalignment$semi_automated_edits/longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] -0.6882714

# %%
summary(lm(longitudinal_misalignment$semi_automated_edits/longitudinal_misalignment$all_edits ~ longitudinal_misalignment$aligned_entities))
# Out:
# Call:
# lm(formula = longitudinal_misalignment$semi_automated_edits/longitudinal_misalignment$all_edits ~
#     longitudinal_misalignment$aligned_entities)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.14172 -0.09315 -0.00724  0.05304  0.34601
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                 0.37732    0.06384   5.910 2.51e-07
# longitudinal_misalignment$aligned_entities -0.47503    0.09910  -4.794 1.37e-05
#
# (Intercept)                                ***
# longitudinal_misalignment$aligned_entities ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.112 on 53 degrees of freedom
# Multiple R-squared:  0.3024,	Adjusted R-squared:  0.2893
# F-statistic: 22.98 on 1 and 53 DF,  p-value: 1.367e-05

# %%
# non_bot edits over all edits versus alignment

# %%
cor(longitudinal_misalignment$aligned_entities, longitudinal_misalignment$non_bot_edits/longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] -0.3139971

# %%
summary(lm(longitudinal_misalignment$non_bot_edits/longitudinal_misalignment$all_edits ~ longitudinal_misalignment$aligned_entities))
# Out:
# Call:
# lm(formula = longitudinal_misalignment$non_bot_edits/longitudinal_misalignment$all_edits ~
#     longitudinal_misalignment$aligned_entities)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.13949 -0.07719 -0.03209  0.03196  0.80590
#
# Coefficients:
#                                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)                                 0.30368    0.08418   3.608 0.000685
# longitudinal_misalignment$aligned_entities -0.15028    0.13067  -1.150 0.255273
#
# (Intercept)                                ***
# longitudinal_misalignment$aligned_entities
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1477 on 53 degrees of freedom
# Multiple R-squared:  0.02435,	Adjusted R-squared:  0.00594
# F-statistic: 1.323 on 1 and 53 DF,  p-value: 0.2553

# %%
# anon edits over all edits versus alignment

# %%
cor(longitudinal_misalignment$aligned_entities, longitudinal_misalignment$anon_edits/longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] 0.3412698

# %%
summary(lm(longitudinal_misalignment$anon_edits/longitudinal_misalignment$all_edits ~ longitudinal_misalignment$aligned_entities))
# Out:
# Call:
# lm(formula = longitudinal_misalignment$anon_edits/longitudinal_misalignment$all_edits ~
#     longitudinal_misalignment$aligned_entities)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0038648 -0.0007972 -0.0001864  0.0012113  0.0056574
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                0.0018177  0.0009334   1.947
# longitudinal_misalignment$aligned_entities 0.0031958  0.0014489   2.206
#                                            Pr(>|t|)
# (Intercept)                                  0.0568 .
# longitudinal_misalignment$aligned_entities   0.0318 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001637 on 53 degrees of freedom
# Multiple R-squared:  0.08407,	Adjusted R-squared:  0.06679
# F-statistic: 4.865 on 1 and 53 DF,  p-value: 0.03177

# %%
#bot edits

# %%
plot(longitudinal_misalignment$bot_edits/longitudinal_misalignment$all_edits)
# Out:
# plot without title

# %%
#semi automated edits

# %%
plot(longitudinal_misalignment$semi_automated_edits/longitudinal_misalignment$all_edits)
# Out:
# plot without title

# %%
#anon automated edits

# %%
plot(longitudinal_misalignment$anon_edits/longitudinal_misalignment$all_edits)
# Out:
# plot without title

# %%
#non_bot edits

# %%
plot(longitudinal_misalignment$non_bot_edits/longitudinal_misalignment$all_edits)
# Out:
# plot without title

# %% [markdown]
# # Correlation between alignment difference and edits

# %%
# Correlation between alignment difference and bot edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$bot_edits/first_month_trimmed_longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] -0.3764056

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$bot_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$bot_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37360 -0.10101  0.00858  0.12249  0.34959
#
# Coefficients:
#                                                                                     Estimate
# (Intercept)                                                                           0.7053
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  -2.4476
#                                                                                     Std. Error
# (Intercept)                                                                             0.0214
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous     1.0502
#                                                                                     t value
# (Intercept)                                                                          32.958
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  -2.331
#                                                                                     Pr(>|t|)
# (Intercept)                                                                           <2e-16
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous   0.0237
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1507 on 52 degrees of freedom
# Multiple R-squared:  0.09457,	Adjusted R-squared:  0.07716
# F-statistic: 5.432 on 1 and 52 DF,  p-value: 0.02369

# %%
# Correlation between alignment difference and current bot edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$current_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count, method="spearman")
# Out:
# [1] -0.434191

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$current_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$current_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.224960 -0.049139  0.003773  0.048630  0.166334
#
# Coefficients:
#                                                                                     Estimate
# (Intercept)                                                                          0.79638
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous -3.47872
#                                                                                     Std. Error
# (Intercept)                                                                            0.01034
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    0.50738
#                                                                                     t value
# (Intercept)                                                                          77.023
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  -6.856
#                                                                                     Pr(>|t|)
# (Intercept)                                                                          < 2e-16
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous 8.39e-09
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0728 on 52 degrees of freedom
# Multiple R-squared:  0.4748,	Adjusted R-squared:  0.4647
# F-statistic: 47.01 on 1 and 52 DF,  p-value: 8.392e-09

# %%
# Correlation between alignment difference and semi-automated edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$semi_automated_edits/first_month_trimmed_longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] 0.4975982

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$semi_automated_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$semi_automated_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.14646 -0.07897 -0.06908  0.07175  0.41196
#
# Coefficients:
#                                                                                     Estimate
# (Intercept)                                                                          0.08820
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  1.15463
#                                                                                     Std. Error
# (Intercept)                                                                            0.01888
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    0.92651
#                                                                                     t value
# (Intercept)                                                                           4.671
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous   1.246
#                                                                                     Pr(>|t|)
# (Intercept)                                                                         2.15e-05
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    0.218
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1329 on 52 degrees of freedom
# Multiple R-squared:  0.029,	Adjusted R-squared:  0.01033
# F-statistic: 1.553 on 1 and 52 DF,  p-value: 0.2183

# %%
# Correlation between alignment difference and current semi-automated edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$current_semi_automated_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count, method="spearman")
# Out:
# [1] 0.3567372

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$current_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_semi_automated_edits_count ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$current_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_semi_automated_edits_count ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -461.24 -306.76   83.38  193.92  418.82
#
# Coefficients:
#                                                                                     Estimate
# (Intercept)                                                                           352.62
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous -6273.86
#                                                                                     Std. Error
# (Intercept)                                                                              38.36
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    1882.33
#                                                                                     t value
# (Intercept)                                                                           9.193
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  -3.333
#                                                                                     Pr(>|t|)
# (Intercept)                                                                         1.75e-12
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  0.00159
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 270.1 on 52 degrees of freedom
# Multiple R-squared:  0.176,	Adjusted R-squared:  0.1602
# F-statistic: 11.11 on 1 and 52 DF,  p-value: 0.001588

# %%
# Correlation between alignment difference and non-bot edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$non_bot_edits/first_month_trimmed_longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] 0.08961311

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$non_bot_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$non_bot_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.20072 -0.07433 -0.02426  0.05960  0.26703
#
# Coefficients:
#                                                                                     Estimate
# (Intercept)                                                                          0.20265
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  1.29893
#                                                                                     Std. Error
# (Intercept)                                                                            0.01421
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    0.69753
#                                                                                     t value
# (Intercept)                                                                          14.256
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous   1.862
#                                                                                     Pr(>|t|)
# (Intercept)                                                                           <2e-16
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous   0.0682
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1001 on 52 degrees of freedom
# Multiple R-squared:  0.06252,	Adjusted R-squared:  0.04449
# F-statistic: 3.468 on 1 and 52 DF,  p-value: 0.06823

# %%
# Correlation between alignment difference and current non-bot edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$current_non_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count, method="spearman")
# Out:
# [1] 0.5108062

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$current_non_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$current_non_bot_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.141364 -0.038878  0.008415  0.024583  0.230914
#
# Coefficients:
#                                                                                     Estimate
# (Intercept)                                                                         0.177031
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous 3.157755
#                                                                                     Std. Error
# (Intercept)                                                                           0.007949
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous   0.390063
#                                                                                     t value
# (Intercept)                                                                          22.271
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous   8.096
#                                                                                     Pr(>|t|)
# (Intercept)                                                                           <2e-16
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    9e-11
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.05596 on 52 degrees of freedom
# Multiple R-squared:  0.5576,	Adjusted R-squared:  0.5491
# F-statistic: 65.54 on 1 and 52 DF,  p-value: 8.996e-11

# %%
# Correlation between alignment difference and anon edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$anon_edits/first_month_trimmed_longitudinal_misalignment$all_edits, method="spearman")
# Out:
# [1] -0.2228702

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$anon_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$anon_edits/first_month_trimmed_longitudinal_misalignment$all_edits ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0030426 -0.0011427 -0.0003832  0.0009429  0.0062052
#
# Coefficients:
#                                                                                       Estimate
# (Intercept)                                                                          0.0038184
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous -0.0060153
#                                                                                     Std. Error
# (Intercept)                                                                          0.0002418
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  0.0118648
#                                                                                     t value
# (Intercept)                                                                          15.792
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  -0.507
#                                                                                     Pr(>|t|)
# (Intercept)                                                                           <2e-16
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    0.614
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001702 on 52 degrees of freedom
# Multiple R-squared:  0.004919,	Adjusted R-squared:  -0.01422
# F-statistic: 0.257 on 1 and 52 DF,  p-value: 0.6143

# %%
# Correlation between alignment difference and current anon edits over all edits

# %%
cor(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous, first_month_trimmed_longitudinal_misalignment$current_anon_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count, method="spearman")
# Out:
# [1] -0.2655613

# %%
summary(lm(first_month_trimmed_longitudinal_misalignment$current_anon_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count ~ first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous))
# Out:
# Call:
# lm(formula = first_month_trimmed_longitudinal_misalignment$current_anon_edits_count/first_month_trimmed_longitudinal_misalignment$current_all_edits_count ~
#     first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0024020 -0.0001983  0.0001506  0.0004013  0.0013727
#
# Coefficients:
#                                                                                       Estimate
# (Intercept)                                                                          3.797e-03
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous -3.656e-03
#                                                                                     Std. Error
# (Intercept)                                                                          9.215e-05
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  4.522e-03
#                                                                                     t value
# (Intercept)                                                                          41.211
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous  -0.809
#                                                                                     Pr(>|t|)
# (Intercept)                                                                           <2e-16
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous    0.422
#
# (Intercept)                                                                         ***
# first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0006488 on 52 degrees of freedom
# Multiple R-squared:  0.01242,	Adjusted R-squared:  -0.006576
# F-statistic: 0.6537 on 1 and 52 DF,  p-value: 0.4225

# %%
min(first_month_trimmed_longitudinal_misalignment$difference_in_alignment_with_previous)
# Out:
# [1] -0.05101577

# %%
first_month_trimmed_longitudinal_misalignment$bot_edit_proportion <- first_month_trimmed_longitudinal_misalignment$bot_edits/first_month_trimmed_longitudinal_misalignment$all_edit

# %%
first_month_trimmed_longitudinal_misalignment$semi_automated_edit_proportion <- first_month_trimmed_longitudinal_misalignment$semi_automated_edits/first_month_trimmed_longitudinal_misalignment$all_edit

# %%
first_month_trimmed_longitudinal_misalignment$non_bot_edit_proportion <- first_month_trimmed_longitudinal_misalignment$non_bot_edits/first_month_trimmed_longitudinal_misalignment$all_edit

# %%
first_month_trimmed_longitudinal_misalignment$anon_edit_proportion <- first_month_trimmed_longitudinal_misalignment$anon_edits/first_month_trimmed_longitudinal_misalignment$all_edit

# %%
first_month_trimmed_longitudinal_misalignment$misaligned_over_aligned <- (1 - first_month_trimmed_longitudinal_misalignment$aligned_entities)/first_month_trimmed_longitudinal_misalignment$aligned_entities

# %%
head(first_month_trimmed_longitudinal_misalignment, n=60)
# Out:
#    yyyymm aligned_entities difference_in_alignment_with_previous bot_edits
# 2  201212 0.8462165         0.0866536670                           183981
# 3  201301 0.9062631         0.0600465527                          1949811
# 4  201302 0.8983001        -0.0079629832                          2337846
# 5  201303 0.9025090         0.0042089126                          2327478
# 6  201304 0.8964184        -0.0060905713                          8256322
# 7  201305 0.8769229        -0.0194954899                         13900943
# 8  201306 0.8388038        -0.0381190921                         14463573
# 9  201307 0.8244444        -0.0143594412                          3850902
# 10 201308 0.8256896         0.0012452362                          8355311
# 11 201309 0.8254115        -0.0002781200                          4091547
# 12 201310 0.8053949        -0.0200166201                          5150692
# 13 201311 0.7880156        -0.0173792434                          8500770
# 14 201312 0.7777810        -0.0102346760                          6840625
# 15 201401 0.7743517        -0.0034293020                          5688500
# 16 201402 0.7701717        -0.0041799537                          8359698
# 17 201403 0.7603903        -0.0097813800                          5062952
# 18 201404 0.7093746        -0.0510157745                          4839056
# 19 201405 0.7128619         0.0034873677                          4412498
# 20 201406 0.6964598        -0.0164021539                          9606783
# 21 201407 0.6910405        -0.0054192489                          4310040
# 44 0.7256545           0.1513806085                   0.12022728
# 45 0.3737059           0.4987139713                   0.12441811
# 46 0.5728411           0.2133915102                   0.21103533
# 47 0.5761582           0.2595747445                   0.16159986
# 48 0.3295181           0.4383286032                   0.22924806
# 49 0.6066544           0.2500038797                   0.14092422
# 50 0.6131495           0.2796843794                   0.10462327
# 51 0.4382990           0.3348400863                   0.22370574
# 52 0.4657460           0.3765800368                   0.15509451
# 53 0.6393705           0.2626305101                   0.09540999
# 54 0.6312306           0.2045018736                   0.16039032
# 55 0.6234902           0.1459194810                   0.22583432
#    anon_edit_proportion misaligned_over_aligned
# 2  0.0067179970         0.1817307
# 3  0.0010412311         0.1034324
# 4  0.0008236917         0.1132138
# 5  0.0030563557         0.1080222
# 6  0.0035376328         0.1155505
# 7  0.0029797822         0.1403511
# 8  0.0028141623         0.1921738
# 9  0.0101098836         0.2129381
# 10 0.0040771596         0.2111088
# 11 0.0081412064         0.2115169
# 12 0.0061322009         0.2416269
# 13 0.0037800020         0.2690103
# 14 0.0045373002         0.2857090
# 15 0.0042374931         0.2914029
# 16 0.0029919174         0.2984117
# 17 0.0054913481         0.3151140
# 18 0.0055895344         0.4096925
# 19 0.0058351926         0.4027962
# 20 0.0032757700         0.4358331
# 21 0.0055089039         0.4470931
# 22 0.0047888894         0.4727262
# 23 0.0054622808         0.5562136
# 24 0.0057568758         0.6139389
# 25 0.0035404838         0.6529326
# 26 0.0056102953         0.7046186
# 27 0.0048384973         0.7353006
# 28 0.0051840578         0.7681342
# 29 0.0039636312         0.8313638
# 30 0.0035450851         0.8791912
# 31 0.0034845533         0.9192277
# 32 0.0031141934         0.9361147
# 33 0.0050642051         0.8924856
# 34 0.0017595098         0.9531487
# 35 0.0032680494         0.9669911
# 36 0.0027260651         1.0009102
# 37 0.0017072326         1.0467173
# 38 0.0025913792         1.0693745
# 39 0.0021266028         1.0703528
# 40 0.0024103406         1.0640251
# 41 0.0035899861         1.0220813
# 42 0.0035780611         1.0287096
# 43 0.0031770951         1.0674189
# 44 0.0027375627         1.1092464
# 45 0.0031620078         1.1148309
# 46 0.0027320751         1.0422957
# 47 0.0026671921         1.0558853
# 48 0.0029052386         1.0520691
# 49 0.0024174688         1.0600951
# 50 0.0025428903         1.0633805
# 51 0.0031551391         1.1014341
# 52 0.0025794800         1.1004292
# 53 0.0025889862         1.1847789
# 54 0.0038772209         1.1872074
# 55 0.0047560318         1.2505668

# %%
attach(first_month_trimmed_longitudinal_misalignment)

# %%
edit_type_regression <- lm(difference_in_alignment_with_previous ~ scale(bot_edits) + scale(semi_automated_edits) + scale(non_bot_edits) + scale(anon_edits))

# %%
summary(edit_type_regression)
# Out:
# Call:
# lm(formula = difference_in_alignment_with_previous ~ scale(bot_edits) +
#     scale(semi_automated_edits) + scale(non_bot_edits) + scale(anon_edits))
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.046292 -0.007201 -0.000022  0.007397  0.056143
#
# Coefficients:
#                              Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 -0.005838   0.002126  -2.746 0.008410 **
# scale(bot_edits)            -0.003788   0.002560  -1.480 0.145339
# scale(semi_automated_edits)  0.006493   0.002336   2.779 0.007702 **
# scale(non_bot_edits)        -0.003144   0.002233  -1.408 0.165418
# scale(anon_edits)           -0.010205   0.002669  -3.823 0.000373 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01562 on 49 degrees of freedom
# Multiple R-squared:  0.4191,	Adjusted R-squared:  0.3717
# F-statistic: 8.839 on 4 and 49 DF,  p-value: 1.87e-05

# %%
independent_and_dependent_variables = data.table(bot_edits = bot_edits, semi_automated_edits = semi_automated_edits, non_bot_edits = non_bot_edits, anon_edits = anon_edits, difference_in_alignment_with_previous = difference_in_alignment_with_previous)

# %%
edit_type_regression_without_anon <- lm(difference_in_alignment_with_previous ~ scale(bot_edits) + scale(semi_automated_edits) + scale(non_bot_edits))

# %%
anon_residuals = data.frame(month=as.Date(paste(yyyymm, "01", sep=""), format="%Y%m%d"), anon_edits = anon_edits, residuals= edit_type_regression_without_anon$residuals)

# %%
summary(anon_residuals)
# Out:
#      month              anon_edits      residuals
#  Min.   :2012-12-01   Min.   : 2087   Min.   :-0.050617
#  1st Qu.:2014-01-08   1st Qu.:27598   1st Qu.:-0.007128
#  Median :2015-02-15   Median :32278   Median :-0.001914
#  Mean   :2015-02-15   Mean   :30848   Mean   : 0.000000
#  3rd Qu.:2016-03-24   3rd Qu.:36700   3rd Qu.: 0.007737
#  Max.   :2017-05-01   Max.   :50381   Max.   : 0.070402

# %%
ggplot(anon_residuals, aes(x=month, y=scale(residuals))) + geom_bar(stat="identity") + geom_line(aes(y=scale(anon_edits)))
# Out:
# plot without title

# %%
hist(scale(anon_residuals$residuals)- scale(anon_residuals$anon_edits))
# Out:
# Plot with title “Histogram of scale(anon_residuals$residuals) - scale(anon_residuals$anon_edits)”

# %%
plot(scale(anon_residuals$residuals), scale(anon_residuals$anon_edits))
# Out:
# plot without title

# %%
cor(independent_and_dependent_variables, method="spearman")
# Out:
#                                       bot_edits  semi_automated_edits
# bot_edits                              1.0000000  0.12893633
# semi_automated_edits                   0.1289363  1.00000000
# non_bot_edits                          0.1108062  0.44830348
# anon_edits                             0.4131504 -0.03351125
# difference_in_alignment_with_previous -0.2967410  0.38536028
#                                       non_bot_edits anon_edits
# bot_edits                              0.11080617    0.41315037
# semi_automated_edits                   0.44830348   -0.03351125
# non_bot_edits                          1.00000000   -0.04417763
# anon_edits                            -0.04417763    1.00000000
# difference_in_alignment_with_previous -0.01330284   -0.32365161
#                                       difference_in_alignment_with_previous
# bot_edits                             -0.29674099
# semi_automated_edits                   0.38536028
# non_bot_edits                         -0.01330284
# anon_edits                            -0.32365161
# difference_in_alignment_with_previous  1.00000000

# %%
VIF(edit_type_regression)
# Out:
# [1] 1.721559

# %%
qqnorm(edit_type_regression$residuals)
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
names(edit_type_regression)
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"
