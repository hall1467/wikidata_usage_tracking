# %%
library(data.table)

# %%
library(plyr)

# %%
library(ggplot2)

# %%
revisions_weighted_sums_and_page_views <- read.table("../../../results/misalignment_edit_types_tables_and_queries/sampled_edit_and_agent_types_10000.tsv", header=TRUE, sep="\t")

# %%
summary(revisions_weighted_sums_and_page_views)
# Out:
#    namespace   page_title         edit_type                  agent_type
#  Min.   :0   Q606787: 272   aliases    :  80   anon_edit          :  68
#  1st Qu.:0   Q567531: 124   claim      :3408   bot_edit           :6879
#  Median :0   Q604130: 122   description:2664   human_edit         :1163
#  Mean   :0   Q61901 : 110   label      : 669   semi_automated_edit:1889
#  3rd Qu.:0   Q580182: 102   NULL       :2806
#  Max.   :0   Q5941  : 102   sitelink   : 372
#              (Other):9167
#   weighted_sum        page_views
#  Min.   :0.002923   Min.   :      0
#  1st Qu.:1.044459   1st Qu.:    285
#  Median :1.860333   Median :   1299
#  Mean   :1.581066   Mean   :  21646
#  3rd Qu.:2.027141   3rd Qu.:   7295
#  Max.   :2.958265   Max.   :2445899

# %%
entity_weighted_sums_and_page_views = data.table(unique(revisions_weighted_sums_and_page_views[,c(1,2,5,6)]))

# %%
summary(entity_weighted_sums_and_page_views)
# Out:
#    namespace    page_title   weighted_sum        page_views
#  Min.   :0   Q5598281:  1   Min.   :0.002923   Min.   :      0.0
#  1st Qu.:0   Q5600770:  1   1st Qu.:0.130284   1st Qu.:    208.5
#  Median :0   Q5601376:  1   Median :0.972744   Median :    803.5
#  Mean   :0   Q5601557:  1   Mean   :0.989430   Mean   :  12402.9
#  3rd Qu.:0   Q5603265:  1   3rd Qu.:1.853863   3rd Qu.:   2959.2
#  Max.   :0   Q5604654:  1   Max.   :2.958265   Max.   :2445899.0
#              (Other) :432

# %%
quantile(entity_weighted_sums_and_page_views$page_views, probs=seq(0,1,.05))
# Out:
#         0%         5%        10%        15%        20%        25%        30%
#       0.00      21.85      58.50     115.65     171.00     208.50     273.10
#        35%        40%        45%        50%        55%        60%        65%
#     365.40     493.80     603.50     803.50     935.05    1166.40    1618.25
#        70%        75%        80%        85%        90%        95%       100%
#    2101.90    2959.25    4608.80    6460.70   10282.80   28606.10 2445899.00

# %%
# entity_weighted_sums_and_page_views$pnorms = pnorm(entity_weighted_sums_and_page_views$page_views, quantile(entity_weighted_sums_and_page_views$page_views, probs=seq(0,1,.05)))

entity_weighted_sums_and_page_views$expected_quality_quantile = ecdf(entity_weighted_sums_and_page_views$page_views)(entity_weighted_sums_and_page_views$page_view)
weighted_sum_distribution = ecdf(entity_weighted_sums_and_page_views$weighted_sum)
entity_weighted_sums_and_page_views$expected_quality = quantile(weighted_sum_distribution, probs=entity_weighted_sums_and_page_views$expected_quality_quantile)
entity_weighted_sums_and_page_views$quality_difference = entity_weighted_sums_and_page_views$expected_quality - entity_weighted_sums_and_page_views$weighted_sum



##andrew scratch:

# %%
head(entity_weighted_sums_and_page_views, n=50)
# Out:
#    namespace page_title weighted_sum page_views expected_quality_quantile
# 1  0         Q5598281   1.004570136     3971    0.875669
# 2  0         Q5600770   0.121259730       44    0.370133
# 3  0         Q5601376   1.919095161     9099    0.923956
# 4  0         Q5601557   1.350748994     2199    0.829241
# 5  0         Q5603265   0.027333708     7526    0.914685
# 6  0         Q5604654   0.170676679      312    0.602583
# 7  0         Q5604954   1.242121573     9745    0.927177
# 8  0         Q5605549   1.829742463     1910    0.816603
# 9  0         Q5610192   0.070499384      950    0.743652
# 10 0         Q5610341   1.716673937      204    0.547597
# 11 0         Q5610456   1.214051419     5468    0.896737
# 12 0         Q5612412   1.114211651     1748    0.808307
# 13 0         Q5613417   0.873709335      543    0.675012
# 14 0         Q5613829   0.033903131    13813    0.941668
# 15 0         Q5616774   1.870664603     2042    0.822614
# ...

# %%
revisions_weighted_sums_and_page_views_with_quality_difference = data.table(join(revisions_weighted_sums_and_page_views, entity_weighted_sums_and_page_views))
# Out:
# Joining by: namespace, page_title, weighted_sum, page_views

# %%
summary(entity_weighted_sums_and_page_views$quality_difference)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -2.976000 -0.604600 -0.006912  0.001554  0.613800  3.829000

# %%
ggplot(entity_weighted_sums_and_page_views,
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference$quality_difference)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -1.0280 -0.2292 -0.3774  0.1683  3.8290

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference,
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases']$quality_difference)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.97600 -0.60880  0.05236  0.09138  0.83730  3.82900

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim']$quality_difference)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -0.9454 -0.1393 -0.2841  0.2604  3.8290

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description']$quality_difference)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -2.976000 -1.188000 -0.281500 -0.524800  0.005132  3.345000

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label']$quality_difference)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.97600 -1.82500 -0.84210 -0.77600 -0.02718  3.82900

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL']$quality_difference)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -0.8955 -0.1828 -0.2987  0.1843  3.8290

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink']$quality_difference)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.96600 -0.61530  0.03271  0.04857  0.78160  3.29500

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference']$quality_difference)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -1.1520 -0.2832 -0.4369  0.1470  3.2950

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier']$quality_difference)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -2.916000 -0.922000 -0.232200 -0.400900  0.005732  3.088000

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit']$quality_difference)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.97600 -1.34600 -0.31090 -0.51570  0.08102  3.29500

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit']$quality_difference)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.97600 -0.75780 -0.08135 -0.07722  0.47870  3.29500

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit']$quality_difference)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.96700 -0.57250  0.02583  0.07231  0.76800  3.82900

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit']$quality_difference)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -0.0725  0.3121  0.4388  0.9565  3.3450

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
# bot edits

summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'
                                                                      ]$quality_difference)
# semi automated edits

summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'
                                                                      ]$quality_difference)

# human edits

summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'
                                                                      ]$quality_difference)

# anon edits

summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
summary(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'
                                                                      ]$quality_difference)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9660 -1.6140 -0.5391 -0.5257  0.1826  3.0880
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.97600 -0.87570 -0.04246 -0.09045  0.77610  2.93000
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9670 -1.8990 -1.6520 -1.1610 -0.3523  3.2950
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.96700 -1.31400 -0.28540 -0.57090 -0.01922  2.83300
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.97600 -1.44200 -0.44200 -0.55580  0.08891  3.25500
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -2.91600 -0.91490 -0.19880 -0.42710 -0.00654  2.68300
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -1.4520 -0.3074 -0.4965  0.1341  3.2550
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -2.9760 -0.9271 -0.2051 -0.3385  0.1478  3.2950
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -2.916000 -0.823100 -0.304700 -0.385100  0.008943  2.849000
# ...

# %% [markdown]
# # Breakdown plots by agent type and edit type

# %% [markdown]
# ## Bot edits

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'bot_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %% [markdown]
# ## Semi-automated edits

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'semi_automated_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %% [markdown]
# ## Human edits

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'human_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %% [markdown]
# ## Anon edits

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'sitelink' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'aliases' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'label' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'description' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'reference' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'qualifier' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'claim' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title

# %%
ggplot(revisions_weighted_sums_and_page_views_with_quality_difference[revisions_weighted_sums_and_page_views_with_quality_difference$edit_type == 'NULL' &
                                                                       revisions_weighted_sums_and_page_views_with_quality_difference$agent_type == 'anon_edit'],
       aes(x=quality_difference)) +
geom_histogram(bins=100);
# Out:
# plot without title
