# %% [markdown]
# # Summary statistics for entity page views

# %%
library(ndjson)

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
entity_values <- stream_in("../results/entity_views_aggregated.json")

# %% [markdown]
# ## All entities

# %%
summary(entity_values)
# Out:
#   entity_id           page_views
#  Length:22250024    Min.   :0.000e+00
#  Class :character   1st Qu.:9.000e+00
#  Mode  :character   Median :1.310e+02
#                     Mean   :2.016e+04
#                     3rd Qu.:9.610e+02
#                     Max.   :1.253e+10

# %%
sd(entity_values$page_views)
# Out:
# [1] 4992682

# %%
sorted_entity_values_by_page_views = dplyr::arrange(entity_values, desc(page_views))

# %%
head(sorted_entity_values_by_page_views, 25)
# Out:
#    entity_id page_views
# 1  Q5296     12530364916
# 2  P373       6423967256
# 3  P18        5286214628
# 4  P856       5113109178
# 5  Q5         4884840396
# 6  P570       3230300124
# 7  Q6581097   3180592597
# 8  P31        3138420518
# 9  P345       3023577978
# 10 P19        2850894926
# 11 P1559      2553682530
# 12 P20        2497468265
# 13 P569       2411879817
# 14 P27        2305105311
# 15 P106       2207579076
# 16 P136       2163841114
# 17 P1477      2150920086
# 18 Q17299517  2105417108
# 19 Q2494649   2068520135
# 20 Q1868372   2056079473
# 21 Q4584301   2052337668
# 22 Q2638147   2045735280
# 23 Q7315186   2045700193
# 24 Q9384291   2045652421
# 25 Q618340    2045597926

# %%
hist(log2(entity_values$page_views))
# Out:
# Plot with title “Histogram of log2(entity_values$page_views)”

# %%
entities_with_no_page_views <- subset(entity_values, page_views==0)

# %% [markdown]
# ## Entities that do not have page views

# %%
summary(entities_with_no_page_views)
# Out:
#   entity_id           page_views
#  Length:1039139     Min.   :0
#  Class :character   1st Qu.:0
#  Mode  :character   Median :0
#                     Mean   :0
#                     3rd Qu.:0
#                     Max.   :0

# %% [markdown]
# ### Percentage of all entity usages that have no page views
